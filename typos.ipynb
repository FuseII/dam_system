# %% [markdown]
# # Определение опечаток

# %%
import numpy as np
import pandas as pd
import symspellpy
import nltk
import string
from tqdm import tqdm
from nltk.corpus import stopwords
import re

# %% [markdown]
# # 1. Загрузка датасета

# %%
df = pd.read_json("data/data.txt", lines=True)
df
# Out:
#                                                     text  \
# 0      1 1 1 Часть территории национального парка "Ло...
# 1      1 1 1 Часть территории национального парка "Ло...
# 2      2 2 2 Часть территории национального парка "Ло...
# 3      3 3 3 Часть территории национального парка "Ло...
# 4      4 4 4 Часть территории национального парка "Ло...
# ...                                                  ...
# 18419  996 996 982 20231117_110117.jpg 2023-11-17 00:...
# 18420  997 997 983 20231121_100442.jpg 2023-11-21 00:...
# 18421  998 998 984 20231121_095847.jpg 2023-11-21 00:...
# 18422  99 99 101 117 4.jpg 2023-11-16 00:00:00+00 13:...
# 18423  999 999 985 20231117_110043.jpg 2023-11-17 00:...
#
#                                                     tags schema_name  \
# 0      [МКА. Геоданные, 440 Особо охраняемые природны...      _46379
# 1      [МКА. Геоданные, 440 Особо охраняемые природны...      _46379
# 2      [МКА. Геоданные, 440 Особо охраняемые природны...      _46379
# 3      [МКА. Геоданные, 440 Особо охраняемые природны...      _46379
# 4      [МКА. Геоданные, 440 Особо охраняемые природны...      _46379
# ...                                                  ...         ...
# 18419  [МКА. Геоданные, 440 Особо охраняемые природны...      _46379
# 18420  [МКА. Геоданные, 440 Особо охраняемые природны...      _46379
# 18421  [МКА. Геоданные, 440 Особо охраняемые природны...      _46379
# 18422  [МКА. Геоданные, 440 Особо охраняемые природны...      _46379
# 18423  [МКА. Геоданные, 440 Особо охраняемые природны...      _46379
#
#       table_name
# 0         _47923
# 1         _58710
# 2         _58710
# 3         _58710
# 4         _58710
# ...          ...
# 18419     _47876
# 18420     _47876
# 18421     _47876
# 18422     _47876
# 18423     _47876
#
# [18424 rows x 4 columns]

# %% [markdown]
# # 2. Предобработка (очистка) датасета

# %%
# Загрузка стоп-слов (один раз при старте)
nltk.download('stopwords')
stop_words = set(stopwords.words('russian')) # Загрузка стоп-слов (один раз при старте)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Функция для очистки текста
def clean_text(text):
    if not isinstance(text, str):
        return ""
    
    # Удаление URL
    text = re.sub(r'http\S+|www\S+|https\S+', ' ', text, flags=re.MULTILINE)
    # Удаление цифр и специальных символов
    text = re.sub(r'\d+', ' ', text)
    # Удаление пунктуации
    # text = text.translate(str.maketrans('', '', string.punctuation))
    text = text.translate(str.maketrans(' ', ' ', string.punctuation))
    # Приведение к нижнему регистру
    text = text.lower()
    # Удаление стоп-слов
    stop_words = set(stopwords.words('russian'))
    words = text.split()
    words = [word for word in words if word not in stop_words and len(word) > 2]
    return ' '.join(words)

# %%
# Функция для обработки чанка с очисткой текста
def process_chunk(chunk):
    """Очистка текста по чанкам"""
    # Очищаем тексты
    cleaned_texts = chunk['text'].apply(clean_text).tolist()
    # Добавляем результаты в чанк
    chunk['cleaned_text'] = cleaned_texts
    return chunk

# %%
# Размер чанка (подбирайте под ваши ресурсы)
CHUNK_SIZE = 1000  
# Инициализация прогресс-бара
pbar = tqdm(total=len(df), desc="Обработка датафрейма")
# Обработка по чанкам
results = []
for i in range(0, len(df), CHUNK_SIZE):
    chunk = df.iloc[i:i + CHUNK_SIZE].copy()
    processed_chunk = process_chunk(chunk)
    results.append(processed_chunk)
    pbar.update(len(chunk))
pbar.close()

# Сборка финального датафрейма
final_df = pd.concat(results, ignore_index=True)
# Out:
# Обработка датафрейма: 100%|██████████| 18424/18424 [00:04<00:00, 3946.67it/s]

# %%
final_df
# Out:
#                                                     text  \
# 0      1 1 1 Часть территории национального парка "Ло...
# 1      1 1 1 Часть территории национального парка "Ло...
# 2      2 2 2 Часть территории национального парка "Ло...
# 3      3 3 3 Часть территории национального парка "Ло...
# 4      4 4 4 Часть территории национального парка "Ло...
# ...                                                  ...
# 18419  996 996 982 20231117_110117.jpg 2023-11-17 00:...
# 18420  997 997 983 20231121_100442.jpg 2023-11-21 00:...
# 18421  998 998 984 20231121_095847.jpg 2023-11-21 00:...
# 18422  99 99 101 117 4.jpg 2023-11-16 00:00:00+00 13:...
# 18423  999 999 985 20231117_110043.jpg 2023-11-17 00:...
#
#                                                     tags schema_name  \
# 0      [МКА. Геоданные, 440 Особо охраняемые природны...      _46379
# 1      [МКА. Геоданные, 440 Особо охраняемые природны...      _46379
# 2      [МКА. Геоданные, 440 Особо охраняемые природны...      _46379
# 3      [МКА. Геоданные, 440 Особо охраняемые природны...      _46379
# 4      [МКА. Геоданные, 440 Особо охраняемые природны...      _46379
# ...                                                  ...         ...
# 18419  [МКА. Геоданные, 440 Особо охраняемые природны...      _46379
# 18420  [МКА. Геоданные, 440 Особо охраняемые природны...      _46379
# 18421  [МКА. Геоданные, 440 Особо охраняемые природны...      _46379
# 18422  [МКА. Геоданные, 440 Особо охраняемые природны...      _46379
# 18423  [МКА. Геоданные, 440 Особо охраняемые природны...      _46379
#
#       table_name                                       cleaned_text
# 0         _47923  часть территории национального парка лосиный о...
# 1         _58710  часть территории национального парка лосиный о...
# 2         _58710  часть территории национального парка лосиный о...
# 3         _58710  часть территории национального парка лосиный о...
# 4         _58710  часть территории национального парка лосиный о...
# ...          ...                                                ...
# 18419     _47876  jpg photoзелаоуч комплексныйзаказникзеленоград...
# 18420     _47876  jpg photoюзаоиюао пип битцевский лесучасток jp...
# 18421     _47876  jpg photoюзаоиюао пип битцевский лесучасток jp...
# 18422     _47876  jpg photoзелаоуч комплексныйзаказникзеленоград...
# 18423     _47876  jpg photoзелаоуч комплексныйзаказникзеленоград...
#
# [18424 rows x 5 columns]

# %% [markdown]
# # 3. Находим опечатки в словах без учёта контекста

# %%
# Инициализация
# sym_spell = symspellpy.SymSpell(max_dictionary_edit_distance=2, prefix_length=7)
# оптимальные настройки для русского языка
sym_spell = symspellpy.SymSpell(
    max_dictionary_edit_distance=2,  # Позволяет исправлять 2 ошибки в слове
    prefix_length=6,                 # Оптимально для слов от 5 символов
    count_threshold=1                # Учитывать даже редкие слова
)

# Загрузка словаря (пример для русского)
# Возможно потребуется открыть файл Notepad и перевести в кодировку UTF-8 BOM
# Notepad++ → «Кодировка» → «Преобразовать в UTF-8-BOM» → Сохранить
dict_path = "ru-100k.txt"  # Файл формата: слово\tчастота
sym_spell.load_dictionary(dict_path, term_index=0, count_index=1, encoding='utf-8')
# Out:
# True

# %%
# Функция для проверки строки
def check_text_for_typos(text, top_k=3):
    """
    Проверяет текст на опечатки и возвращает предложения исправлений.
    
    Параметры:
        text: строка для проверки
        top_k: количество предлагаемых исправлений
    
    Возвращает:
        dict: {
            'has_typo': bool,
            'corrections': {слово: [исправления]}
        }
    """
    words = text.split()
    result = {'has_typo': False, 'corrections': {}}
    
    for word in words:
        # Игнорируем слова с цифрами/спецсимволами
        if not word.isalpha():
            continue
            
        suggestions = sym_spell.lookup(word, symspellpy.Verbosity.TOP, max_edit_distance=2)
        
        if suggestions and (suggestions[0].term != word.lower()):
            result['has_typo'] = True
            result['corrections'][word] = [sug.term for sug in suggestions[:top_k]]
    
    return result

# %%
# Проверка всего датасета
def process_row(row):
    return check_text_for_typos(row['cleaned_text'])

# %%
final_df['typo_info'] = final_df.apply(process_row, axis=1)

# Разбиваем результат на отдельные колонки
final_df['has_typo'] = final_df['typo_info'].apply(lambda x: x['has_typo'])
final_df['corrections'] = final_df['typo_info'].apply(lambda x: x['corrections'])

# Отображаем проблемные строки
print(final_df[final_df['has_typo']][['cleaned_text', 'corrections']])
# Out:
#                                             cleaned_text  \
# 0      часть территории национального парка лосиный о...
# 1      часть территории национального парка лосиный о...
# 2      часть территории национального парка лосиный о...
# 3      часть территории национального парка лосиный о...
# 4      часть территории национального парка лосиный о...
# ...                                                  ...
# 18415  jpg photoюзаоиюао пип битцевский лесучасток jp...
# 18416  jpg photoюзаоиюао пип битцевский лесучасток jp...
# 18417  jpg photoюзаоиюао пип битцевский лесучасток jp...
# 18420  jpg photoюзаоиюао пип битцевский лесучасток jp...
# 18421  jpg photoюзаоиюао пип битцевский лесучасток jp...
#
#                                              corrections
# 0      {'лосиный': ['ложный'], 'ппрф': ['при'], 'утве...
# 1      {'лосиный': ['ложный'], 'ппм': ['пом'], 'зон':...
# 2      {'лосиный': ['ложный'], 'ппм': ['пом'], 'рекре...
# 3      {'лосиный': ['ложный'], 'ппм': ['пом'], 'рекре...
# 4      {'лосиный': ['ложный'], 'ппм': ['пом'], 'рекре...
# ...                                                  ...
# 18415                                   {'пип': ['тип']}
# 18416                                   {'пип': ['тип']}
# 18417                                   {'пип': ['тип']}
# 18420                                   {'пип': ['тип']}
# 18421                                   {'пип': ['тип']}
#
# [12390 rows x 2 columns]

# %%
final_df
# Out:
#                                                     text  \
# 0      1 1 1 Часть территории национального парка "Ло...
# 1      1 1 1 Часть территории национального парка "Ло...
# 2      2 2 2 Часть территории национального парка "Ло...
# 3      3 3 3 Часть территории национального парка "Ло...
# 4      4 4 4 Часть территории национального парка "Ло...
# ...                                                  ...
# 18419  996 996 982 20231117_110117.jpg 2023-11-17 00:...
# 18420  997 997 983 20231121_100442.jpg 2023-11-21 00:...
# 18421  998 998 984 20231121_095847.jpg 2023-11-21 00:...
# 18422  99 99 101 117 4.jpg 2023-11-16 00:00:00+00 13:...
# 18423  999 999 985 20231117_110043.jpg 2023-11-17 00:...
#
#                                                     tags schema_name  \
# 0      [МКА. Геоданные, 440 Особо охраняемые природны...      _46379
# 1      [МКА. Геоданные, 440 Особо охраняемые природны...      _46379
# 2      [МКА. Геоданные, 440 Особо охраняемые природны...      _46379
# 3      [МКА. Геоданные, 440 Особо охраняемые природны...      _46379
# 4      [МКА. Геоданные, 440 Особо охраняемые природны...      _46379
# ...                                                  ...         ...
# 18419  [МКА. Геоданные, 440 Особо охраняемые природны...      _46379
# 18420  [МКА. Геоданные, 440 Особо охраняемые природны...      _46379
# 18421  [МКА. Геоданные, 440 Особо охраняемые природны...      _46379
# 18422  [МКА. Геоданные, 440 Особо охраняемые природны...      _46379
# 18423  [МКА. Геоданные, 440 Особо охраняемые природны...      _46379
#
#       table_name                                       cleaned_text  \
# 0         _47923  часть территории национального парка лосиный о...
# 1         _58710  часть территории национального парка лосиный о...
# 2         _58710  часть территории национального парка лосиный о...
# 3         _58710  часть территории национального парка лосиный о...
# 4         _58710  часть территории национального парка лосиный о...
# ...          ...                                                ...
# 18419     _47876  jpg photoзелаоуч комплексныйзаказникзеленоград...
# 18420     _47876  jpg photoюзаоиюао пип битцевский лесучасток jp...
# 18421     _47876  jpg photoюзаоиюао пип битцевский лесучасток jp...
# 18422     _47876  jpg photoзелаоуч комплексныйзаказникзеленоград...
# 18423     _47876  jpg photoзелаоуч комплексныйзаказникзеленоград...
#
#                                                typo_info  has_typo  \
# 0      {'has_typo': True, 'corrections': {'лосиный': ...      True
# 1      {'has_typo': True, 'corrections': {'лосиный': ...      True
# 2      {'has_typo': True, 'corrections': {'лосиный': ...      True
# 3      {'has_typo': True, 'corrections': {'лосиный': ...      True
# 4      {'has_typo': True, 'corrections': {'лосиный': ...      True
# ...                                                  ...       ...
# 18419             {'has_typo': False, 'corrections': {}}     False
# 18420  {'has_typo': True, 'corrections': {'пип': ['ти...      True
# 18421  {'has_typo': True, 'corrections': {'пип': ['ти...      True
# 18422             {'has_typo': False, 'corrections': {}}     False
# 18423             {'has_typo': False, 'corrections': {}}     False
#
#                                              corrections
# 0      {'лосиный': ['ложный'], 'ппрф': ['при'], 'утве...
# 1      {'лосиный': ['ложный'], 'ппм': ['пом'], 'зон':...
# 2      {'лосиный': ['ложный'], 'ппм': ['пом'], 'рекре...
# 3      {'лосиный': ['ложный'], 'ппм': ['пом'], 'рекре...
# 4      {'лосиный': ['ложный'], 'ппм': ['пом'], 'рекре...
# ...                                                  ...
# 18419                                                 {}
# 18420                                   {'пип': ['тип']}
# 18421                                   {'пип': ['тип']}
# 18422                                                 {}
# 18423                                                 {}
#
# [18424 rows x 8 columns]

# %%
new_words = set()
for row in final_df[final_df['has_typo'] == True]['typo_info']:
    new_words.update(row['corrections'].keys())
with open('new_words.txt', 'w', encoding='utf-8') as f:
    for word in new_words:
        f.write(word + ' 1000\n')

# %%
# Тест 1: Слово без ошибок (должно вернуть пустой список)
sym_spell = symspellpy.SymSpell(
    max_dictionary_edit_distance=2,  # Позволяет исправлять 2 ошибки в слове
    prefix_length=3,                 # Оптимально для слов от 5 символов
    count_threshold=1                # Учитывать даже редкие слова
)
# Загрузка словаря (пример для русского)
dict_path = r"D:\Artem\Projects\dam_system\ru-100k.txt"  # Файл формата: слово\tчастота
sym_spell.load_dictionary(dict_path, term_index=0, count_index=1, encoding="utf-8")
result = sym_spell.lookup("толька", symspellpy.Verbosity.ALL, max_edit_distance=2)
l = [sug.term for sug in result]
print(l)
# Out:
# ['только', 'толка', 'колька', 'толчка', 'талька', 'полька', 'толика', 'столько', 'тока', 'полка', 'точка', 'молока', 'кольца', 'ольга', 'толпа', 'польша', 'тоска', 'толку', 'толща', 'польза', 'волка', 'толь', 'толк', 'больна', 'толки', 'столика', 'томска', 'тельца', 'галька', 'валька', 'толчки', 'ролика', 'поляка', 'толкая', 'юлька', 'толкал', 'вольта', 'конька', 'тонка', 'дольки', 'ольха', 'горька', 'гольца', 'мольба', 'толику', 'танька', 'алька', 'тальк', 'кольку', 'волчка', 'калька', 'телка']

# %%
print("только" in sym_spell.words)  # Должно быть True
# Out:
# False

# %%
sym_spell.words
# Out:
# {'Рё': 1954983899,
#  'РІ': 1777896533,
#  'РЅР°': 757220470,
#  'СЃ': 573730702,
#  'РЅРµ': 572922286,
#  'С‡С‚Рѕ': 423162044,
#  'РїРѕ': 371606009,
#  'Рє': 290282744,
#  'Р°': 280904669,
#  'РґР»СЏ': 246215536,
#  'РєР°Рє': 244551527,
#  'Рѕ': 228326808,
#  'РёР·': 212856406,
#  'РµРіРѕ': 199670915,
#  'РѕС‚': 186911686,
#  'РїСЂРё': 178988616,
#  'РЅРѕ': 176843721,
#  'Р·Р°': 170509258,
#  'РѕРЅ': 164510273,
#  'СЏ': 157023312,
#  'Сѓ': 141115495,
#  'Р¶Рµ': 132247321,
#  'РІСЃРµ': 131259213,
#  'РёР»Рё': 119797047,
#  'РёС…': 112369672,
#  'РґРѕ': 108670301,
#  'С‚Р°Рє': 107533512,
#  'С‚РѕР»СЊРєРѕ': 105890951,
#  'Р±С‹Р»Рѕ': 104357562,
#  'РµРµ': 83253365,
#  'РјС‹': 82296922,
#  'РІРѕ': 78871081,
#  'РѕРЅРё': 78842003,
#  'Р±С‹': 78147359,
#  'РµС‰Рµ': 72840601,
#  'РѕРЅР°': 72308740,
#  'РµСЃР»Рё': 70375161,
#  'РІСЂРµРјСЏ': 69406295,
#  'Р±С‹Р»': 69345894,
#  'РєРѕРіРґР°': 64889145,
#  'Р±РѕР»РµРµ': 63737041,
#  'Р±С‹Р»Рё': 63697786,
#  'С‚Р°РєР¶Рµ': 63352916,
#  'СѓР¶Рµ': 62412105,
#  'Р±С‹С‚СЊ': 61251930,
#  'СЃРѕ': 55045013,
#  'С‡С‚РѕР±С‹': 54409034,
#  'РјРµР¶РґСѓ': 53337117,
#  'С‚РѕРіРѕ': 51761728,
#  'СЌС‚РѕРіРѕ': 51680074,
#  'РјРѕР¶РЅРѕ': 51384460,
#  'Р±С‹Р»Р°': 50176405,
#  'СЌС‚РѕРј': 49107420,
#  'РїРѕРґ': 49092849,
#  'РїРѕСЃР»Рµ': 47990055,
#  'РЅРё': 47860640,
#  'РєРѕС‚РѕСЂС‹Рµ': 47678010,
#  'С‚РѕРј': 47469012,
#  'РіРґРµ': 43921300,
#  'С‡РµРј': 43668765,
#  'РІСЃРµС…': 42949655,
#  'РјРЅРµ': 42190035,
#  'РµРјСѓ': 41713178,
#  'РѕР±': 41064245,
#  'РґР°Р¶Рµ': 40454204,
#  'СЌС‚РѕР№': 40431781,
#  'РґР°': 40382508,
#  'СЌС‚Рё': 40229542,
#  'РіРѕРґР°': 40189356,
#  'С‚РµРј': 40171852,
#  'РµСЃС‚СЊ': 39423106,
#  'РІСЃРµРіРѕ': 39402840,
#  'РјРµРЅСЏ': 39308021,
#  'Р±РµР·': 37641643,
#  'РѕС‡РµРЅСЊ': 37453912,
#  'Р¶РёР·РЅРё': 37208766,
#  'СЃСЃСЃСЂ': 37029026,
#  'Р·РґРµСЃСЊ': 36541896,
#  'РЅРёС…': 36172622,
#  'СЏРІР»СЏРµС‚СЃСЏ': 35158728,
#  'Р»Рё': 34611911,
#  'СЌС‚РёС…': 34344705,
#  'РІС‹': 34086225,
#  'РѕРґРЅР°РєРѕ': 33845733,
#  'СЌС‚РѕС‚': 33605550,
#  'РєРѕС‚РѕСЂС‹Р№': 33490357,
#  'СЃРµР±СЏ': 33268179,
#  'С‚С‹': 33085676,
#  'СЂР°Р±РѕС‚С‹': 33085322,
#  'Р»РёС€СЊ': 32764209,
#  'Р±СѓРґРµС‚': 32230456,
#  'РІСЂРµРјРµРЅРё': 31860173,
#  'РЅРµС‚': 31588780,
#  'РёРј': 31469672,
#  'С‡РµСЂРµР·': 31355978,
#  'РІРѕС‚': 30871044,
#  'РЅРµРіРѕ': 30298963,
#  'СЃРІРѕРµР№': 29749813,
#  'РєРѕС‚РѕСЂС‹С…': 29744222,
#  'РѕР±Р»Р°СЃС‚Рё': 29534623,
#  'РґСЂСѓРіРёС…': 29481444,
#  'РѕР±СЂР°Р·РѕРј': 28267680,
#  'С‚РѕРіРґР°': 27930951,
#  'Р»РµС‚': 27922388,
#  'СЂР°Р·РІРёС‚РёСЏ': 27581977,
#  'С‚РµРїРµСЂСЊ': 27460629,
#  'РЅР°СЃ': 26595562,
#  'СЃР»СѓС‡Р°Рµ': 26197059,
#  'СЂР°Р·': 25880047,
#  'С‚Р°Рј': 25691546,
#  'РЅРµСЃРєРѕР»СЊРєРѕ': 25565690,
#  'С‡Р°СЃС‚Рё': 25345644,
#  'РѕРґРёРЅ': 25241022,
#  'СЃРµР±Рµ': 25031355,
#  'РЅР°Рґ': 24695657,
#  'СЃРІСЏР·Рё': 24685543,
#  'С‡РµР»РѕРІРµРє': 24133135,
#  'Р±РѕР»СЊС€Рµ': 23860462,
#  'РєРѕС‚РѕСЂРѕР№': 23829791,
#  'РґРІР°': 23551753,
#  'СЂРѕСЃСЃРёРё': 23446576,
#  'РїСЂРѕРёР·РІРѕРґСЃС‚РІР°': 23404372,
#  'С…РѕС‚СЏ': 23305512,
#  'РЅР°РїСЂРёРјРµСЂ': 23106103,
#  'РїРµСЂРµРґ': 23097692,
#  'СЃРёСЃС‚РµРјС‹': 22804868,
#  'СЃРІРѕСЋ': 22775187,
#  'РіРѕРґСѓ': 22719780,
#  'С‚СЂСѓРґР°': 22574603,
#  'РїРѕС‡С‚Рё': 22373388,
#  'С‡РµР»РѕРІРµРєР°': 22117242,
#  'С‚Р°РєРёРј': 22031903,
#  'СЌС‚Р°': 22000224,
#  'С‡Р°СЃС‚СЊ': 21866756,
#  'РёРјРµРµС‚': 21743378,
#  'РїРѕСЌС‚РѕРјСѓ': 21706319,
#  'Р»СЋРґРµР№': 21695218,
#  'СЃС‚РѕСЂРѕРЅС‹': 21515805,
#  'РєС‚Рѕ': 21500401,
#  'РЅР°РґРѕ': 21386707,
#  'РѕРґРЅРѕР№': 21233749,
#  'Р¶РёР·РЅСЊ': 21192273,
#  'РїРѕС‚РѕРјСѓ': 21167248,
#  'РѕСЃРѕР±РµРЅРЅРѕ': 21126326,
#  'СЃР»РµРґСѓРµС‚': 20957421,
#  'РїСЂРѕС‚РёРІ': 20926855,
#  'РєРѕС‚РѕСЂР°СЏ': 20723397,
#  'РІСЃРµРіРґР°': 20684633,
#  'РЅР°РёР±РѕР»РµРµ': 20674302,
#  'СЃРІРѕРµРіРѕ': 20617157,
#  'С‚Р°РєРѕР№': 20407390,
#  'РјРЅРѕРіРѕ': 20192792,
#  'СЃРІРѕРёС…': 20034136,
#  'РёСЃС‚РѕСЂРёРё': 19916170,
#  'Р·РЅР°С‡РµРЅРёРµ': 19723232,
#  'РґРµР»Рѕ': 19683130,
#  'РґСЂСѓРіРѕР№': 19614229,
#  'РЅР°Рј': 19506737,
#  'РґРµРЅСЊ': 19230850,
#  'СЃСЂРµРґРё': 19222375,
#  'РЅРµР№': 18941218,
#  'СѓСЃР»РѕРІРёСЏС…': 18910030,
#  'РІРјРµСЃС‚Рµ': 18638003,
#  'РіРѕРґС‹': 18438860,
#  'СЃРІРѕРё': 18433591,
#  'РґРµСЏС‚РµР»СЊРЅРѕСЃС‚Рё': 18349148,
#  'СЂРёСЃ': 18348877,
#  'РѕРЅРѕ': 18101279,
#  'СЃР»РѕРІР°': 17887435,
#  'СЃРѕР±РѕР№': 17860060,
#  'РґРІСѓС…': 17856348,
#  'РјРµСЃС‚Рѕ': 17816215,
#  'РєСЂРѕРјРµ': 17782992,
#  'СЃРєР°Р·Р°Р»': 17744887,
#  'РѕСЂРіР°РЅРёР·Р°С†РёРё': 17716947,
#  'РґРѕР»Р¶РЅС‹': 17602259,
#  'РЅРёС‡РµРіРѕ': 17485528,
#  'СЃС‚СЂР°РЅС‹': 17444034,
#  'Р±': 17434975,
#  'РѕР±С‰РµСЃС‚РІР°': 17234325,
#  'С‚РµС…': 17045867,
#  'РѕРґРЅРѕРіРѕ': 16979758,
#  'С‚СЂРё': 16804505,
#  'С…РѕСЂРѕС€Рѕ': 16756283,
#  'РїР°СЂС‚РёРё': 16718128,
#  'РІРѕР№РЅС‹': 16703302,
#  'РґСЂСѓРіРёРµ': 16606133,
#  'РЅРёРј': 16568908,
#  'СЃРІРѕРµ': 16522399,
#  'РІС‹С€Рµ': 16477041,
#  'РїРµСЂРёРѕРґ': 16376067,
#  'РІРѕРїСЂРѕСЃ': 16352394,
#  'СЃР°Рј': 16310973,
#  'РїСЂРµР¶РґРµ': 16195514,
#  'РІСЃРµРј': 16145279,
#  'СЂР°Р±РѕС‚Рµ': 16036917,
#  'СЌС‚РёРј': 16021316,
#  'РєРѕС‚РѕСЂРѕРіРѕ': 15957617,
#  'СЂР°Р±РѕС‡РёС…': 15845300,
#  'РѕРєРѕР»Рѕ': 15803968,
#  'С‚РѕС‚': 15803622,
#  'Р»СЋРґРё': 15730765,
#  'СЂРѕР»СЊ': 15718153,
#  'СЃРµР№С‡Р°СЃ': 15567906,
#  'С…РѕР·СЏР№СЃС‚РІР°': 15532717,
#  'СЂР°Р·Р»РёС‡РЅС‹С…': 15427363,
#  'С‚Рµ': 15259264,
#  'С‚РѕРјСѓ': 14946266,
#  'РєРѕРЅРµС‡РЅРѕ': 14927869,
#  'С‚СѓС‚': 14853918,
#  'РїРѕС‚РѕРј': 14805480,
#  'РЅРµРєРѕС‚РѕСЂС‹Рµ': 14727332,
#  'РіРѕРґ': 14719039,
#  'РєРѕС‚РѕСЂРѕРµ': 14710899,
#  'РјРµРЅРµРµ': 14595036,
#  'РІС‚РѕСЂРѕР№': 14537884,
#  'РІСЃРµР№': 14496070,
#  'С‚РѕР¶Рµ': 14471756,
#  'РІРёРґРµ': 14366506,
#  'РЅР°С€РµР№': 14272135,
#  'РЅРµРѕР±С…РѕРґРёРјРѕ': 14238290,
#  'Р·Р°С‚РµРј': 14188373,
#  'РіРѕ': 14079570,
#  'РІРѕРїСЂРѕСЃС‹': 13971977,
#  'РІРµРґСЊ': 13947801,
#  'СЃРєР°Р·Р°С‚СЊ': 13943680,
#  'С‚Р°РєРёС…': 13894195,
#  'С‡РёСЃР»Рѕ': 13880855,
#  'РµР№': 13875881,
#  'РЅР°СЃРµР»РµРЅРёСЏ': 13855775,
#  'СЌС‚Сѓ': 13719040,
#  'РІР»Р°СЃС‚Рё': 13694216,
#  'РЅРµР»СЊР·СЏ': 13631660,
#  'С‚РѕР№': 13621086,
#  'С‚Р°РєРѕРµ': 13585307,
#  'РёСЃСЃР»РµРґРѕРІР°РЅРёСЏ': 13506421,
#  'СЂР°Р·РІРёС‚РёРµ': 13504705,
#  'РїРѕРєР°': 13425146,
#  'РІРµСЃСЊРјР°': 13416128,
#  'С„РѕСЂРјС‹': 13335795,
#  'РѕСЃРЅРѕРІРµ': 13322992,
#  'СЃРѕРІРµСЂС€РµРЅРЅРѕ': 13316475,
#  'С‚РёРїР°': 13301550,
#  'РєСѓР»СЊС‚СѓСЂС‹': 13224006,
#  'С‡Р°СЃС‚Рѕ': 13184201,
#  'С‚Р°РєРёРµ': 13183521,
#  'РіСЂСѓРїРїС‹': 13170904,
#  'РЅРµРј': 13119593,
#  'РїРµСЂРІС‹Р№': 13039767,
#  'РІРѕР·РјРѕР¶РЅРѕСЃС‚СЊ': 13037380,
#  'СЃС‚РµРїРµРЅРё': 13015144,
#  'С‡РµРіРѕ': 12937391,
#  'РєР°С‡РµСЃС‚РІРµ': 12872223,
#  'СѓРїСЂР°РІР»РµРЅРёСЏ': 12846126,
#  'СЏРІР»СЏСЋС‚СЃСЏ': 12817792,
#  'Р·РµРјР»Рё': 12743004,
#  'РїСЂРѕРјС‹С€Р»РµРЅРЅРѕСЃС‚Рё': 12729833,
#  'РјРёСЂР°': 12633003,
#  'С‡РёСЃР»Рµ': 12613000,
#  'РІР°СЃ': 12610298,
#  'РЅР°СЂРѕРґР°': 12606855,
#  'СЂРµР·СѓР»СЊС‚Р°С‚С‹': 12527140,
#  'РґРѕР»Р¶РµРЅ': 12518323,
#  'РІР»РёСЏРЅРёРµ': 12478765,
#  'РЅСѓР¶РЅРѕ': 12437374,
#  'Р±РѕР»СЊС€РѕР№': 12395918,
#  'СЃС‚Р°Р»Рё': 12339835,
#  'РЅСѓ': 12304039,
#  'РєР°Р¶РґС‹Р№': 12293251,
#  'РєРѕР»РёС‡РµСЃС‚РІРѕ': 12271645,
#  'РІРЅРёРјР°РЅРёРµ': 12268167,
#  'РѕРґРЅР°': 12247419,
#  'СЂРµР·СѓР»СЊС‚Р°С‚Рµ': 12200193,
#  'СЃРёР»С‹': 12188202,
#  'РЅРµРµ': 12186761,
#  'С‚РµР±СЏ': 12164944,
#  'СЌС‚РѕРјСѓ': 12129603,
#  'С…Р°СЂР°РєС‚РµСЂ': 12092062,
#  'СЃРѕРІРµС‚Р°': 12091581,
#  'РЅРѕРІС‹С…': 12075694,
#  'СѓСЃР»РѕРІРёСЏ': 12030984,
#  'РѕРґРЅРѕ': 11995360,
#  'С‚РµС‡РµРЅРёРµ': 11992985,
#  'РїСЂРѕРґСѓРєС†РёРё': 11945916,
#  'РІР°Рј': 11942681,
#  'СЃРІРѕР№': 11889769,
#  'РјРµСЂРµ': 11852895,
#  'РІРѕРґС‹': 11847772,
#  'РґРІРёР¶РµРЅРёСЏ': 11822212,
#  'РЅРµРєРѕС‚РѕСЂС‹С…': 11772989,
#  'СЂСѓСЃСЃРєРѕР№': 11767179,
#  'РґР°РЅРЅС‹Рµ': 11739530,
#  'СЃС€Р°': 11673988,
#  'РІРѕРѕР±С‰Рµ': 11627250,
#  'РґРѕР»Р¶РЅРѕ': 11588309,
#  'РґРЅСЏ': 11583113,
#  'РёРЅРѕРіРґР°': 11480403,
#  'РїРµСЂРІРѕР№': 11453756,
#  'РїСѓС‚Рё': 11416531,
#  'РґРІРµ': 11394860,
#  'РїСЂРѕР±Р»РµРјС‹': 11387159,
#  'РєРѕ': 11374487,
#  'РѕР±СЂР°Р·РѕРІР°РЅРёСЏ': 11316781,
#  'Р·РЅР°С‡РµРЅРёСЏ': 11298444,
#  'РЅРѕРІС‹Рµ': 11294544,
#  'СЂР°Р±РѕС‚Сѓ': 11288534,
#  'РґРѕСЃС‚Р°С‚РѕС‡РЅРѕ': 11285172,
#  'Р·Р°РґР°С‡Рё': 11175439,
#  'СЂРѕСЃСЃРёР№СЃРєРѕР№': 11168280,
#  'С‚РµР±Рµ': 11143054,
#  'РґСЂСѓРі': 11102867,
#  'РіРѕСЂРѕРґР°': 11093864,
#  'РёРјРµСЋС‚': 11089403,
#  'СЂРµС€РµРЅРёСЏ': 11077816,
#  'РЅР°РјРё': 11064461,
#  'С‚Р°РєРѕРіРѕ': 11046720,
#  'Р·Р°РІРёСЃРёРјРѕСЃС‚Рё': 11015600,
#  'РєРѕРЅС†Рµ': 11005354,
#  'РјРЅРѕРіРёРµ': 10981781,
#  'РїРѕР»РѕР¶РµРЅРёРµ': 10981052,
#  'РіРѕРІРѕСЂРёС‚': 10970861,
#  'РїСЂР°РІР°': 10916613,
#  'РіРѕСЃСѓРґР°СЂСЃС‚РІР°': 10859340,
#  'С‚Р°': 10854778,
#  'СЃРІРѕРёРј': 10822195,
#  'Р±СѓРґСѓС‚': 10812620,
#  'РїСЂР°РІРѕ': 10779298,
#  'СЂСЏРґ': 10766519,
#  'РІРµСЃСЊ': 10766213,
#  'РЅР°СѓРєРё': 10724580,
#  'РґРѕР»Р¶РЅР°': 10672181,
#  'РїРѕС‡РµРјСѓ': 10639725,
#  'РґРµР»Р°': 10630945,
#  'СЂР°Р±РѕС‚Р°': 10624473,
#  'СЂРµРІРѕР»СЋС†РёРё': 10624332,
#  'Р»РёС‚РµСЂР°С‚СѓСЂС‹': 10622038,
#  'СЃРѕРґРµСЂР¶Р°РЅРёРµ': 10597447,
#  'РёР·РјРµРЅРµРЅРёСЏ': 10577090,
#  'С‚РѕС‡РєРё': 10550301,
#  'РєРѕС‚РѕСЂРѕРј': 10504790,
#  'РјРЅРѕРіРёС…': 10484791,
#  'РїРѕРјРѕС‰СЊСЋ': 10470192,
#  'РєРЅРёРіРё': 10440069,
#  'РїРѕРІРµСЂС…РЅРѕСЃС‚Рё': 10410364,
#  'РЅРёРєРѕРіРґР°': 10386522,
#  'СЂРµС€РµРЅРёРµ': 10385443,
#  'РЅРёРјРё': 10245246,
#  'РїСЂРµРґРїСЂРёСЏС‚РёР№': 10244541,
#  'РѕС‚РґРµР»СЊРЅС‹С…': 10228807,
#  'Р·РЅР°С‡РёС‚РµР»СЊРЅРѕ': 10195526,
#  'РјР°Р»Рѕ': 10160475,
#  'РІРѕР·РјРѕР¶РЅРѕСЃС‚Рё': 10142274,
#  'СЃРѕРІРµС‚СЃРєРѕР№': 10130447,
#  'С‚РµРѕСЂРёРё': 10110520,
#  'РїСѓС‚РµРј': 10095495,
#  'СЃР»РѕРІРѕ': 10085155,
#  'РјРёСЂ': 10052947,
#  'СЃРѕРІРµС‚СЃРєРѕРіРѕ': 10052222,
#  'РїРѕСЃРєРѕР»СЊРєСѓ': 10043870,
#  'Р±СѓРґС‚Рѕ': 10026368,
#  'РіР»Р°Р·Р°': 10024525,
#  'РїСЂР°РІРґР°': 10020792,
#  'С„СѓРЅРєС†РёРё': 10005041,
#  'СЏР·С‹РєР°': 10003476,
#  'РЅР°СѓС‡РЅРѕ': 9993109,
#  'РґРѕРјР°': 9966493,
#  'РІСЃСЋ': 9908063,
#  'РїСЂРѕС†РµСЃСЃ': 9855638,
#  'РѕС‚РЅРѕС€РµРЅРёРё': 9853664,
#  'С„РµРґРµСЂР°С†РёРё': 9846162,
#  'С‡Р°СЃС‚РЅРѕСЃС‚Рё': 9836787,
#  'СЃС‡РµС‚': 9813996,
#  'СЂРµСЃРїСѓР±Р»РёРєРё': 9798099,
#  'РґР°РЅРЅС‹С…': 9757240,
#  'РјРѕР№': 9734542,
#  'РѕС‚РЅРѕСЃРёС‚РµР»СЊРЅРѕ': 9729383,
#  'РІРёРґРЅРѕ': 9715040,
#  'СЂРѕРґР°': 9698363,
#  'СЃРѕРІСЃРµРј': 9689115,
#  'Р»СѓС‡С€Рµ': 9683810,
#  'СЃРµРіРѕРґРЅСЏ': 9677519,
#  'Р°РІС‚РѕСЂ': 9618215,
#  'СЃС‚': 9607871,
#  'РёР·РІРµСЃС‚РЅРѕ': 9604103,
#  'СЃРёСЃС‚РµРјР°': 9587217,
#  'СЃРѕСЃС‚Р°РІ': 9562597,
#  'СЂСѓРєРё': 9557998,
#  'РЅР°С‡Р°Р»Р°': 9549856,
#  'СЃРёР»Сѓ': 9527809,
#  'РёРґРµС‚': 9515234,
#  'Р±РѕСЂСЊР±С‹': 9490945,
#  'РЅРѕРІРѕР№': 9481948,
#  'СЃРѕСЋР·Р°': 9478586,
#  'РєРѕС‚РѕСЂСѓСЋ': 9462646,
#  'РіРѕРІРѕСЂРёС‚СЊ': 9453028,
#  'СЃСЂР°Р·Сѓ': 9404398,
#  'РґРѕРІРѕР»СЊРЅРѕ': 9403953,
#  'РїСЂРѕС†РµСЃСЃР°': 9334620,
#  'СЃРЅРѕРІР°': 9329459,
#  'РѕС‚РЅРѕС€РµРЅРёСЏ': 9316263,
#  'РІРѕР·РјРѕР¶РЅРѕ': 9297365,
#  'РѕР±С‹С‡РЅРѕ': 9240042,
#  'РґРµР№СЃС‚РІРёСЏ': 9239817,
#  'РїСѓСЃС‚СЊ': 9205813,
#  'РЅР°С€Рё': 9195081,
#  'РїСЂРёС‡РµРј': 9193760,
#  'РІРїРѕР»РЅРµ': 9185456,
#  'СЃР°РјРѕРіРѕ': 9163972,
#  'Р°СЂРјРёРё': 9139158,
#  'С‡РёСЃР»Р°': 9134727,
#  'Р»РёР±Рѕ': 9121813,
#  'РѕРґРЅРёРј': 9108293,
#  'РґРµР№СЃС‚РІРёС‚РµР»СЊРЅРѕ': 9095877,
#  'РґРµС‚РµР№': 9093722,
#  'СѓСЃР»РѕРІРёР№': 9043452,
#  'РЅР°РєРѕРЅРµС†': 8960275,
#  'СЃРєРѕР»СЊРєРѕ': 8956573,
#  'РѕСЃРѕР±РµРЅРЅРѕСЃС‚Рё': 8953956,
#  'РЅР°СЃС‚РѕСЏС‰РµРµ': 8908442,
#  'РёСЃС‚РѕСЂРёСЏ': 8891974,
#  'РїСЂРѕ': 8886805,
#  'СЂР°Р·РЅС‹С…': 8874769,
#  'РїСѓС‚СЊ': 8855855,
#  'СЃРґРµР»Р°С‚СЊ': 8784537,
#  'СЃР»СѓС‡Р°СЏС…': 8782316,
#  'Р°РЅР°Р»РёР·': 8779988,
#  'РїРѕР»СЏ': 8778375,
#  'РјРј': 8766645,
#  'РґР°РµС‚': 8747755,
#  'СЂСѓСЃСЃРєРѕРіРѕ': 8669786,
#  'РґРЅРµР№': 8666836,
#  'СЃР»РµРґРѕРІР°С‚РµР»СЊРЅРѕ': 8640592,
#  'РІСЃСЏ': 8600203,
#  'Р·СЂРµРЅРёСЏ': 8597111,
#  'РїРёСЃР°Р»': 8594801,
#  'РІРµРєР°': 8567950,
#  'СЃРІРѕРµРј': 8566500,
#  'РЅР°С€РµРіРѕ': 8558788,
#  'РјР°С‚РµСЂРёР°Р»С‹': 8490929,
#  'РґРµСЏС‚РµР»СЊРЅРѕСЃС‚СЊ': 8481521,
#  'РѕСЃРЅРѕРІРЅС‹С…': 8441728,
#  'РєР°РєРѕР№': 8431862,
#  'РѕРїС‹С‚': 8427620,
#  'СЃС‚СЂР°РЅРµ': 8419868,
#  'С‚РµСЂСЂРёС‚РѕСЂРёРё': 8417320,
#  'РїСЂРѕРёСЃС…РѕРґРёС‚': 8414701,
#  'РІРёРґ': 8407040,
#  'РёР±Рѕ': 8394408,
#  'РЅРµСЃРјРѕС‚СЂСЏ': 8382202,
#  'РѕС‚РЅРѕС€РµРЅРёР№': 8378082,
#  'СЃС‚Р°С‚СЊРё': 8326261,
#  'РІРґСЂСѓРі': 8320737,
#  'РЅРѕРІРѕРіРѕ': 8319627,
#  'С†РµР»РѕРј': 8312008,
#  'РЅРѕРІС‹Р№': 8305709,
#  'РѕРїСЂРµРґРµР»РµРЅРёСЏ': 8299432,
#  'РїРѕРјРѕС‰Рё': 8289378,
#  'РёР·-Р·Р°': 8284172,
#  'РѕРїСЏС‚СЊ': 8267910,
#  'РЅР°СЂРѕРґРЅРѕРіРѕ': 8230840,
#  'РЅР°С‡Р°Р»Рµ': 8229984,
#  'РґРµР»Рµ': 8165069,
#  'РєР°Р¶РµС‚СЃСЏ': 8140677,
#  'РЅР°С€РёС…': 8139878,
#  'РїСЂР°РІРёС‚РµР»СЊСЃС‚РІР°': 8127880,
#  'Р±РѕР»СЊС€РѕРµ': 8116948,
#  'РїРѕСЃР»РµРґРЅРёРµ': 8110626,
#  'Р»РёС‚РµСЂР°С‚СѓСЂР°': 8079528,
#  'СЃР°РјРѕР№': 8070676,
#  'РЅРёР¶Рµ': 8070137,
#  'СЃРѕРіР»Р°СЃРЅРѕ': 8020419,
#  'РјРµС‚РѕРґ': 7997750,
#  'РѕСЃРЅРѕРІРЅС‹Рµ': 7987616,
#  'РјРµСЃС‚Р°': 7980772,
#  'СЌР»РµРјРµРЅС‚РѕРІ': 7964090,
#  'СѓР¶': 7951431,
#  'Р°РЅ': 7935165,
#  'Р·РЅР°С‡РёС‚': 7915783,
#  'РєР°Р¶РґРѕРіРѕ': 7914794,
#  'РёРјРµС‚СЊ': 7907116,
#  'СЃРёСЃС‚РµРјРµ': 7896366,
#  'С‚Р°РєР°СЏ': 7890135,
#  'РѕРґРЅРѕРІСЂРµРјРµРЅРЅРѕ': 7874787,
#  'Р±С‹СЃС‚СЂРѕ': 7865856,
#  'Р»РёС†Р°': 7865039,
#  'СѓСЂРѕРІРЅСЏ': 7856957,
#  'СЂР°Р·Р°': 7853521,
#  'РјС‹СЃР»Рё': 7842680,
#  'С‚СЂРµС…': 7837889,
#  'С‚РѕС‡РЅРѕ': 7815379,
#  'СЃС‚РѕСЂРѕРЅСѓ': 7815345,
#  'РёСЃРїРѕР»СЊР·РѕРІР°РЅРёСЏ': 7790611,
#  'РЅР°СЂРѕРґРѕРІ': 7789293,
#  'Р»РёС†Рѕ': 7786174,
#  'СЂРµС‡СЊ': 7762410,
#  'РіРѕРІРѕСЂРёР»': 7737553,
#  'РґСЂСѓРіРёРјРё': 7735536,
#  'РјР°С‚РµСЂРёР°Р»РѕРІ': 7731567,
#  'РїРѕР»РЅРѕСЃС‚СЊСЋ': 7689637,
#  'РёСЃРєСѓСЃСЃС‚РІР°': 7687756,
#  'СЃС‚СЂСѓРєС‚СѓСЂС‹': 7687643,
#  'СЃРІРѕРµРјСѓ': 7645344,
#  'РІРёРґРѕРІ': 7643993,
#  'С„РѕСЂРјРµ': 7641016,
#  'РїРѕР·РІРѕР»СЏРµС‚': 7637707,
#  'СЂСѓР±': 7634639,
#  'РїРѕР»Рµ': 7625335,
#  'СЂР°Р±РѕС‡РµРіРѕ': 7622774,
#  'РјРµРЅСЊС€Рµ': 7621950,
#  'РїРёСЃСЊРјРѕ': 7620736,
#  'РїСЂРµРґСЃС‚Р°РІР»СЏРµС‚': 7620170,
#  'РЅР°С€': 7601129,
#  'Р»РµРЅРёРЅ': 7568176,
#  'РёСЃСЃР»РµРґРѕРІР°РЅРёР№': 7551893,
#  'СЃРѕРѕС‚РІРµС‚СЃС‚РІРёРё': 7542408,
#  'РєРѕС‚РѕСЂС‹Рј': 7530452,
#  'С€РєРѕР»С‹': 7530380,
#  'С†РµР»СЊСЋ': 7530146,
#  'РїСЂРѕС†РµСЃСЃРµ': 7499410,
#  'РїСЂРѕС†РµСЃСЃРѕРІ': 7482854,
#  'РѕС‡РµСЂРµРґСЊ': 7481222,
#  'СЃС‚СЂРѕРёС‚РµР»СЊСЃС‚РІР°': 7465671,
#  'РёРјСЏ': 7451900,
#  'РІРёРґСѓ': 7440194,
#  'РїРµСЂРІРѕРіРѕ': 7424390,
#  'РѕСЂРіР°РЅРёР·Р°С†РёР№': 7422280,
#  'СЃР°РјРѕРј': 7416468,
#  'РјРѕСЃРєРІР°': 7390417,
#  'СЌРЅРµСЂРіРёРё': 7377644,
#  'СЃР°РјРё': 7372842,
#  'СЃРѕРѕС‚РІРµС‚СЃС‚РІРµРЅРЅРѕ': 7352050,
#  'РѕР±Р»Р°СЃС‚СЊ': 7346246,
#  'Р»РµРіРєРѕ': 7330326,
#  'РЅРµРјСѓ': 7317973,
#  'СЂРѕСЃС‚Р°': 7313029,
#  'РєР»Р°СЃСЃР°': 7312892,
#  'РїСЂРѕРёР·РІРѕРґСЃС‚РІРѕ': 7307388,
#  'РѕРєС‚СЏР±СЂСЏ': 7291020,
#  'РєРїСЃСЃ': 7283797,
#  'Р°РЅР°Р»РёР·Р°': 7270407,
#  'РїРѕР»РѕР¶РµРЅРёСЏ': 7252463,
#  'РѕС‡РµРІРёРґРЅРѕ': 7230418,
#  'РІРјРµСЃС‚Рѕ': 7219580,
#  'РІРїРµСЂРІС‹Рµ': 7196701,
#  'РїРµСЂРІС‹Рµ': 7182324,
#  'Р»РёРЅРёРё': 7178895,
#  'РѕРґРЅРѕРј': 7175602,
#  'СЂСЏРґРѕРј': 7171617,
#  'РіРѕСЃСѓРґР°СЂСЃС‚РІРµРЅРЅРѕР№': 7169007,
#  'С‡С‚Рѕ-С‚Рѕ': 7167919,
#  'РїРѕСЂСЏРґРєР°': 7166675,
#  'СЃСЂРµРґСЃС‚РІР°': 7160423,
#  'С†РµСЂРєРІРё': 7156817,
#  'СЃРѕСЃС‚Р°РІР°': 7148212,
#  'РєСѓРґР°': 7146261,
#  'СЂСЏРґР°': 7125191,
#  'РјР°СЂС‚Р°': 7113732,
#  'РёРјРµРЅРё': 7104123,
#  'СЃСЂР°РІРЅРµРЅРёСЋ': 7086993,
#  'РјР°СЏ': 7082846,
#  'РІРЅРѕРІСЊ': 7077025,
#  'СЃС‚Р°РЅРѕРІРёС‚СЃСЏ': 7076985,
#  'Р·РЅР°СЋ': 7075763,
#  'РЅРёРєС‚Рѕ': 7063708,
#  'РѕРґРЅСѓ': 7055383,
#  'РѕС‚РЅРѕС€РµРЅРёРµ': 7049292,
#  'РєРѕРЅС†Р°': 7046587,
#  'РјРѕСЃРєРІРµ': 7044006,
#  'СЏР·С‹Рє': 7031186,
#  'РґРѕРј': 7027237,
#  'РїРѕР»РёС‚РёС‡РµСЃРєРѕР№': 7007687,
#  'РіР»Р°РІРЅС‹Рј': 6991001,
#  'СЃРІСЏР·СЊ': 6990371,
#  'СЃР°РјРѕРµ': 6985119,
#  'РґРІРёР¶РµРЅРёРµ': 6984086,
#  'РґР°Р»РµРµ': 6980914,
#  'С†Рє': 6967709,
#  'СЃРёР»СЊРЅРѕ': 6925952,
#  'РґР°РІРЅРѕ': 6925811,
#  'РёРЅС„РѕСЂРјР°С†РёРё': 6918463,
#  'РїРѕР»РёС‚РёРєРё': 6906778,
#  'РІС‹Рї': 6905187,
#  'РѕР±С‰РµР№': 6903594,
#  'СЃС‚РѕР»СЊ': 6893988,
#  'РїСЂР°РІРёС‚РµР»СЊСЃС‚РІРѕ': 6891471,
#  'СЃРјРµСЂС‚Рё': 6891174,
#  'СЂР°Р№РѕРЅР°': 6843269,
#  'РєР°Р¶РґРѕР№': 6832290,
#  'СЃРєРѕСЂРѕСЃС‚Рё': 6822723,
#  'СЃРІРѕРёРјРё': 6818484,
#  'РјРµСЃС‚Рµ': 6811622,
#  'СѓС‡Р°СЃС‚РёРµ': 6790528,
#  'Р±Р»Р°РіРѕРґР°СЂСЏ': 6780536,
#  'РёСЃСЃР»РµРґРѕРІР°РЅРёРµ': 6767090,
#  'СЏР·С‹РєРµ': 6751444,
#  'СѓСЂРѕРІРµРЅСЊ': 6744140,
#  'РїСЂСЏРјРѕ': 6727211,
#  'РєРЅ': 6724730,
#  'РґСЂСѓРіР°': 6715980,
#  'РЅР°СЂРѕРґ': 6712286,
#  'РјС‹СЃР»СЊ': 6710009,
#  'РґР°Р»РµРєРѕ': 6704506,
#  'РїСЂРµРґРїСЂРёСЏС‚РёСЏ': 6702679,
#  'СЂРµР°РєС†РёРё': 6700822,
#  'РіРѕРґРѕРІ': 6699688,
#  'РЅР°С…РѕРґРёС‚СЃСЏ': 6692202,
#  'РјРѕРјРµРЅС‚': 6641388,
#  'РѕСЃРЅРѕРІРЅРѕРј': 6628286,
#  'СЂСѓСЃСЃРєРёС…': 6621274,
#  'С‚СЂСѓРґРЅРѕ': 6595702,
#  'СЃР°РјС‹Рј': 6583176,
#  'РЅР°С‡Р°Р»Рѕ': 6581736,
#  'РґР°РЅРЅС‹Рј': 6553393,
#  'СЂР°Р±РѕС‚РЅРёРєРѕРІ': 6549212,
#  'Р¶': 6542801,
#  'СЂР°СЃС‚РµРЅРёР№': 6541314,
#  'С‚РµРјРїРµСЂР°С‚СѓСЂС‹': 6538789,
#  'СЂР°РЅРµРµ': 6537266,
#  'РІРµР»РёС‡РёРЅС‹': 6534204,
#  'РїСЂРµРґРµР»Р°С…': 6506737,
#  'Р±РѕСЂСЊР±Рµ': 6498261,
#  'СЃСЂРµРґРЅРµР№': 6492669,
#  'РѕР±Р»': 6482764,
#  'РѕСЂРіР°РЅРѕРІ': 6476409,
#  'СЃРѕСЃС‚Р°РІР»СЏРµС‚': 6467896,
#  'РїРµСЂРІС‹С…': 6459618,
#  'РіРѕСЂРѕРґ': 6436815,
#  'РѕРїСЂРµРґРµР»СЏРµС‚СЃСЏ': 6432661,
#  'Р·Р°РґР°С‡Р°': 6422940,
#  'СЂРѕР»Рё': 6421959,
#  'РёРЅСЃС‚РёС‚СѓС‚Р°': 6412003,
#  'С‚Р°Р±Р»': 6411934,
#  'РґРѕР»РіРѕ': 6399063,
#  'РґРЅРё': 6393939,
#  'РѕР±С‰РµРіРѕ': 6393934,
#  'СЃР°РјР°': 6385172,
#  'СЃРј': 6363839,
#  'РјРµС‚РѕРґС‹': 6360168,
#  'С…Р°СЂР°РєС‚РµСЂР°': 6350297,
#  'СЂРѕСЃС‚': 6337538,
#  'РЅР°СѓРєР°': 6324400,
#  'С‡Р»РµРЅРѕРІ': 6310283,
#  'РѕСЃС‚Р°РµС‚СЃСЏ': 6302199,
#  'С‚СЂСѓРґСЏС‰РёС…СЃСЏ': 6300850,
#  'Р»РµРЅРёРЅР°': 6299905,
#  'СЏРЅРІР°СЂСЏ': 6299387,
#  'РЅРµРїРѕСЃСЂРµРґСЃС‚РІРµРЅРЅРѕ': 6299140,
#  'РїРёСЃСЊРјР°': 6286843,
#  'РІР»Р°СЃС‚СЊ': 6286289,
#  'РґР°С‚СЊ': 6285889,
#  'СЃРѕС†РёР°Р»РёСЃС‚РёС‡РµСЃРєРѕРіРѕ': 6283952,
#  'СЃС‚РѕРёС‚': 6270604,
#  'С‚РµС…РЅРёРєРё': 6269171,
#  'РЅР°Р·Р°Рґ': 6255933,
#  'РІРѕРєСЂСѓРі': 6248243,
#  'Р·Р°РІРёСЃРёС‚': 6245508,
#  'СЃСѓС‰РµСЃС‚РІСѓРµС‚': 6237476,
#  'РѕР±СЂР°Р·РѕРІР°РЅРёРµ': 6232773,
#  'РєР°С‡РµСЃС‚РІР°': 6227137,
#  'РїРѕРјРѕС‰СЊ': 6225479,
#  'СЏСЃРЅРѕ': 6222121,
#  'РіРѕСЃСѓРґР°СЂСЃС‚РІРµРЅРЅРѕРіРѕ': 6212928,
#  'С‡РµС‚С‹СЂРµ': 6210537,
#  'Р·Р°РІРёСЃРёРјРѕСЃС‚СЊ': 6209423,
#  'СЃРѕСЃС‚РѕРёС‚': 6191350,
#  'РґРµР»Р°С‚СЊ': 6188936,
#  'РїСЂР°РєС‚РёС‡РµСЃРєРё': 6163121,
#  'СЃРѕРґРµСЂР¶Р°РЅРёСЏ': 6162737,
#  'РІРѕРїСЂРѕСЃСѓ': 6156610,
#  'С€РёСЂРѕРєРѕ': 6140490,
#  'СЃРѕСЃС‚РѕСЏРЅРёРµ': 6138388,
#  'СЃС‡РёС‚Р°С‚СЊ': 6131930,
#  'РіРѕР»РѕРІСѓ': 6121228,
#  'СЂР°РЅСЊС€Рµ': 6119771,
#  'Р±СѓРґРµРј': 6119665,
#  'РїР»Р°РЅ': 6113510,
#  'СѓСЂР°РІРЅРµРЅРёСЏ': 6111152,
#  'СЂРµС‡Рё': 6097828,
#  'РјРёСЂРµ': 6097575,
#  'СЃРѕРІРµС‚СЃРєРёС…': 6095981,
#  'Р»РёС‚РµСЂР°С‚СѓСЂРµ': 6092749,
#  'РёСЋР»СЏ': 6090036,
#  'СЃРµР»СЊСЃРєРѕРіРѕ': 6072035,
#  'РёРЅСЃС‚РёС‚СѓС‚': 6067263,
#  'СЌРєРѕРЅРѕРјРёС‡РµСЃРєРѕР№': 6058361,
#  'Р°РІРіСѓСЃС‚Р°': 6037502,
#  'Р°РєР°РґРµРјРёРё': 6037373,
#  'СЃРѕС†РёР°Р»СЊРЅРѕ': 6031941,
#  'С‚Р°Р±Р»РёС†Р°': 6025052,
#  'РёРјРё': 6021734,
#  'РёР·Рґ': 6021469,
#  'РёСЋРЅСЏ': 6013958,
#  'РїСЂРёСЂРѕРґС‹': 6013701,
#  'РѕСЃРЅРѕРІР°РЅРёРё': 6008572,
#  'СЃРѕСЃС‚РѕСЏРЅРёРё': 6002120,
#  'РїСЂРёРІРѕРґРёС‚': 6002072,
#  'РёРЅР°С‡Рµ': 5997935,
#  'СЃРѕСЃС‚РѕСЏРЅРёСЏ': 5987443,
#  'РЅРѕСЏР±СЂСЏ': 5984319,
#  'СЃС‚Р°С‚СЊСЏ': 5972398,
#  'СЂР°РІРЅРѕ': 5964791,
#  'РґРµРєР°Р±СЂСЏ': 5953673,
#  'С‚Сѓ': 5933340,
#  'РёР·СѓС‡РµРЅРёСЏ': 5927219,
#  'РєРѕРјРёС‚РµС‚Р°': 5920348,
#  'РєРј': 5916424,
#  'РіРѕРІРѕСЂСЏ': 5913554,
#  'РґСЂСѓРіРёРј': 5901280,
#  'С…РѕС‚СЊ': 5900958,
#  'СЂСѓСЃСЃРєРёР№': 5900004,
#  'РєРЅРёРіР°': 5897052,
#  'РїСЂР°РІРёР»Рѕ': 5893973,
#  'РјР°С‚РµСЂРёР°Р»Р°': 5890859,
#  'СѓРґР°Р»РѕСЃСЊ': 5889913,
#  'Р°РІС‚РѕСЂР°': 5885269,
#  'РіСЂСѓРїРїР°': 5879881,
#  'РІРµСЂРѕСЏС‚РЅРѕ': 5876068,
#  'Р±РѕР»СЊС€СѓСЋ': 5869714,
#  'СЂР°Р№РѕРЅРµ': 5838600,
#  'РїРµСЂРІСѓСЋ': 5833243,
#  'РёР·СѓС‡РµРЅРёРµ': 5828420,
#  'РѕС‚РјРµС‚РёС‚СЊ': 5823802,
#  'РјРѕРґРµР»Рё': 5822514,
#  'СЌРєРѕРЅРѕРјРёРєРё': 5812438,
#  'РєРѕРіРѕ': 5789692,
#  'СЃР»РѕРІРЅРѕ': 5771688,
#  'РїРѕСЃС‚РѕСЏРЅРЅРѕ': 5763969,
#  'РѕР±С‰РµСЃС‚РІРµРЅРЅРѕРіРѕ': 5755131,
#  'СЃРІРѕР№СЃС‚РІР°': 5752104,
#  'СЃСЂРµРґС‹': 5751543,
#  'СЃРµРЅС‚СЏР±СЂСЏ': 5739976,
#  'СЂР°Р·РІРёС‚РёРё': 5734384,
#  'РїР»РѕС‰Р°РґРё': 5725185,
#  'РЅРµРѕР±С…РѕРґРёРјРѕСЃС‚СЊ': 5723610,
#  'РєР°Р·Р°Р»РѕСЃСЊ': 5723107,
#  'СЂРµР·РєРѕ': 5722059,
#  'РјРѕСЏ': 5721585,
#  'РґР°Р»СЊС€Рµ': 5719744,
#  'Р·РµРјР»СЋ': 5713515,
#  'РїСЂРёРјРµРЅРµРЅРёРµ': 5709466,
#  'РїРѕСЃР»РµРґРЅРµРµ': 5708935,
#  'РїРѕР»СѓС‡РёС‚СЊ': 5708251,
#  'РІРёРґР°': 5707367,
#  'СЃРµСЂРґС†Рµ': 5706092,
#  'РґРµР»': 5700559,
#  'РёРјРµРµС‚СЃСЏ': 5681059,
#  'РёРЅС‚РµСЂРµСЃ': 5680935,
#  'РІСЃРµРјРё': 5671305,
#  'РёСЃРїРѕР»СЊР·РѕРІР°РЅРёРµ': 5670381,
#  'СЃРјС‹СЃР»Рµ': 5665661,
#  'Р¶РёС‚СЊ': 5653314,
#  'СЂСѓРєСѓ': 5653159,
#  'РёР·РјРµРЅРµРЅРёРµ': 5642302,
#  'РїСЂРѕРёР·РІРµРґРµРЅРёСЏ': 5637060,
#  'Р¶РёРІРѕС‚РЅС‹С…': 5629611,
#  'РїРµСЂРІР°СЏ': 5629024,
#  'СЃС‚СЂР°РЅР°С…': 5620645,
#  'СЃРёСЃС‚РµРјСѓ': 5613237,
#  'РјР°С‚СЊ': 5611392,
#  'РїРѕСЂСЏРґРєРµ': 5609799,
#  'РѕРїСЂРµРґРµР»РµРЅРёРµ': 5593477,
#  'Р±РѕР»СЊС€Р°СЏ': 5591830,
#  'РѕСЃРЅРѕРІРЅРѕР№': 5591769,
#  'Р·РµРјР»Рµ': 5591542,
#  'РїСЏС‚СЊ': 5590222,
#  'СЌРєРѕРЅРѕРјРёС‡РµСЃРєРѕРіРѕ': 5584983,
#  'С†РµР»Рё': 5568629,
#  'С„РѕСЂРјР°': 5561042,
#  'Р·Р°РїР°РґРЅРѕР№': 5553808,
#  'РІРЅСѓС‚СЂРё': 5552736,
#  'РјРµС‚РѕРґРѕРј': 5537266,
#  'РґРµР№СЃС‚РІРёРµ': 5529880,
#  'СЂР°СЃРїСЂРµРґРµР»РµРЅРёСЏ': 5521626,
#  'РґРµРЅСЊРіРё': 5517452,
#  'РЅРѕРІРѕРµ': 5505418,
#  'РЅР°Р№С‚Рё': 5499778,
#  'СЂР°Р·Р»РёС‡РЅС‹Рµ': 5499100,
#  'РѕР±С‰РµСЃС‚РІРѕ': 5489720,
#  'РґР°РЅРЅРѕР№': 5489701,
#  'РґРІСѓРјСЏ': 5482232,
#  'СЃРѕС†РёР°Р»РёР·РјР°': 5463205,
#  'СЃРµ': 5456007,
#  'С„СѓРЅРєС†РёР№': 5453421,
#  'СЌРєРѕРЅРѕРјРёС‡РµСЃРєРёС…': 5451540,
#  'РїРµСЂРёРѕРґР°': 5444710,
#  'Р°РїСЂРµР»СЏ': 5440329,
#  'СѓС‡РµС‚РѕРј': 5431996,
#  'РІРѕРїСЂРѕСЃРѕРІ': 5429860,
#  'РјР°СЃСЃС‹': 5422969,
#  'С‡Р°СЃ': 5409387,
#  'РЅР°Р·РІ': 5404872,
#  'РіРѕРІРѕСЂСЏС‚': 5401111,
#  'РІРѕРїСЂРѕСЃР°': 5398217,
#  'СЃР»РёС€РєРѕРј': 5396492,
#  'Р·Р°РєРѕРЅР°': 5389237,
#  'РѕС‚РµС†': 5387166,
#  'РѕС‚СЃСЋРґР°': 5382022,
#  'РѕС†РµРЅРєРё': 5375338,
#  'СЃР»СѓС‡Р°Р№': 5374632,
#  'СЃРЅР°С‡Р°Р»Р°': 5370575,
#  'РјРЅРµРЅРёСЋ': 5370257,
#  'РІР·РіР»СЏРґ': 5364911,
#  'РјРёСЂРѕРІРѕР№': 5354569,
#  'РІСЃР»РµРґСЃС‚РІРёРµ': 5344067,
#  'СЃРєРѕСЂРѕСЃС‚СЊ': 5335785,
#  'СЃРѕР·РґР°РЅРёСЏ': 5311158,
#  'С‚РµР»Р°': 5308952,
#  'Р±РѕР»СЊС€РёС…': 5305769,
#  'Р±РѕСЂСЊР±Р°': 5300609,
#  'РЅР°С€Р°': 5298044,
#  'РєРѕС‚РѕСЂРѕРјСѓ': 5297498,
#  'Р±РѕР»СЊС€РёРЅСЃС‚РІРѕ': 5285154,
#  'РѕРїС‹С‚Р°': 5277644,
#  'РїРёС€РµС‚': 5267574,
#  'СЃРІРµС‚': 5261937,
#  'СЃР°РјС‹Р№': 5250799,
#  'Р·РѕРЅС‹': 5246712,
#  'РіР»Р°РІРЅРѕРµ': 5245004,
#  'СЃРёР±РёСЂРё': 5244215,
#  'РѕСЂРіР°РЅРёР·Р°С†РёСЏ': 5238670,
#  'РЅРѕС‡СЊ': 5230776,
#  'РЅР°СЂСЏРґСѓ': 5222631,
#  'РІРµСЃС‚Рё': 5213842,
#  'СЃР°РјС‹С…': 5210970,
#  'РіР°': 5207571,
#  'РјРµС‚РѕРґРѕРІ': 5206973,
#  'РїРµС‡Р°С‚Рё': 5197954,
#  'РјРѕРµР№': 5193911,
#  'РІС‹СЃРѕРєРѕР№': 5192535,
#  'РїСЂРёРјРµСЂРЅРѕ': 5192480,
#  'СЃР»РµРґСѓСЋС‰РёРµ': 5189070,
#  'РґСЂСѓРіРѕРіРѕ': 5185472,
#  'С‚СЂСѓРґ': 5176312,
#  'РєР°СЃР°РµС‚СЃСЏ': 5170216,
#  'РјР°С‚РµСЂРёР°Р»': 5167781,
#  'РёРІР°РЅ': 5164114,
#  'РёСЃРїРѕР»СЊР·РѕРІР°С‚СЊ': 5143278,
#  'РјРѕСЂСЏ': 5140351,
#  'СѓСЂРѕРІРЅРµ': 5136939,
#  'СЃС‚Р°С‚СЊРµ': 5136934,
#  'РЅРµРѕР±С…РѕРґРёРјРѕСЃС‚Рё': 5130135,
#  'РєР°РєРёРµ': 5114210,
#  'С‡С‚РѕР±': 5110110,
#  'РјРµСЂС‹': 5104711,
#  'РєСЂСѓРїРЅС‹С…': 5100014,
#  'РµРґРІР°': 5096341,
#  'РІР»РёСЏРЅРёСЏ': 5082409,
#  'РїРѕРєР°Р·С‹РІР°РµС‚': 5080157,
#  'РєРѕРЅС†РµРЅС‚СЂР°С†РёРё': 5074310,
#  'РїСЂРёРјРµРЅРµРЅРёСЏ': 5068841,
#  'РїСЂРѕРіСЂР°РјРјС‹': 5049809,
#  'РїРѕРІС‹С€РµРЅРёСЏ': 5048130,
#  'С„РµРІСЂР°Р»СЏ': 5043185,
#  'СЃРѕРІРµС‚': 5042775,
#  'РїРµСЂРІРѕРµ': 5033818,
#  'СЃРµРІРµСЂРѕ': 5026048,
#  'РјРѕСЃРєРІС‹': 5022848,
#  'СЃС‚РѕР»СЊРєРѕ': 5018534,
#  'СЃРєРѕСЂРѕ': 5018512,
#  'Р»СЋР±РѕРІСЊ': 5017841,
#  'Р±РѕР»СЊС€РµР№': 5015163,
#  'РЅР°С‡Р°Р»': 5013757,
#  'РєРѕР»РёС‡РµСЃС‚РІР°': 4999441,
#  'РІРµР»РёРєРѕР№': 4999119,
#  'РєСЂР°СЏ': 4998177,
#  'СЃРїСЂРѕСЃРёР»': 4986903,
#  'РїР°': 4977729,
#  'СЃРєР°Р·Р°Р»Р°': 4967139,
#  'СЃРѕСЃС‚Р°РІРµ': 4966093,
#  'Р·Р°РєРѕРЅ': 4961055,
#  'РґСЂСѓРіРѕРµ': 4947706,
#  'СЂРѕСЃСЃРёСЏ': 4947568,
#  'РіРѕР»РѕСЃ': 4943532,
#  'РїРѕСЂСЏРґРѕРє': 4940154,
#  'РїСЂРёРЅСЏС‚СЊ': 4939035,
#  'РјРѕСЂРµ': 4937849,
#  'РЅР°СѓС‡РЅС‹С…': 4916220,
#  'РѕР±СЂР°Р·': 4916027,
#  'СЃРѕС†РёР°Р»РёСЃС‚РёС‡РµСЃРєРѕР№': 4915988,
#  'Р»РёС‡РЅРѕСЃС‚Рё': 4915187,
#  'СЃСѓРґР°': 4914299,
#  'СЂРµР·СѓР»СЊС‚Р°С‚РѕРІ': 4897450,
#  'РЅР°РїСЂР°РІР»РµРЅРёРё': 4893728,
#  'СЌС„С„РµРєС‚РёРІРЅРѕСЃС‚Рё': 4887249,
#  'РЅР°Р»РёС‡РёРµ': 4881709,
#  'РјРѕРё': 4863106,
#  'РІРѕРїСЂРѕСЃР°Рј': 4849174,
#  'РєРЅРёРіРµ': 4846768,
#  'РїР»Р°РЅР°': 4841774,
#  'РѕС‚РЅРѕС€РµРЅРёСЋ': 4833141,
#  'РіР»Р°РІР°': 4832022,
#  'СЃРІРµРґРµРЅРёСЏ': 4827455,
#  'РІРёРґРµР»': 4816007,
#  'РѕС‚РґРµР»СЊРЅС‹Рµ': 4815926,
#  'СЃРѕР·РґР°РЅРёРµ': 4799039,
#  'РѕС‚РІРµС‚': 4783640,
#  'РёРјРµР»Рё': 4780703,
#  'РїРµСЂРІРѕРј': 4768667,
#  'РІРёРґРµС‚СЊ': 4767921,
#  'РїСЂРёС…РѕРґРёС‚СЃСЏ': 4758971,
#  'С‡Р°С‰Рµ': 4753039,
#  'С…РѕС‚РµР»': 4751458,
#  'РІРµР»РёС‡РёРЅР°': 4748710,
#  'РЅРµРІРѕР·РјРѕР¶РЅРѕ': 4746790,
#  'РЅРµСЃРєРѕР»СЊРєРёС…': 4744917,
#  'СЂСѓР±Р»РµР№': 4744044,
#  'СЃСЋРґР°': 4742825,
#  'РґРµ': 4734700,
#  'РІРёРґРёРјРѕРјСѓ': 4729483,
#  'РµСЃС‚РµСЃС‚РІРµРЅРЅРѕ': 4727717,
#  'Р»СЋР±РІРё': 4725321,
#  'СЂР°Р№РѕРЅР°С…': 4724109,
#  'РјРЅРѕР¶РµСЃС‚РІРѕ': 4719300,
#  'РєРѕС‚РѕСЂС‹РјРё': 4712319,
#  'РєРѕРјРёСЃСЃРёРё': 4705303,
#  'РѕРєР°Р·С‹РІР°РµС‚СЃСЏ': 4701093,
#  'С„СѓРЅРєС†РёСЏ': 4699833,
#  'РїРѕС‡РІС‹': 4697209,
#  'С‡СѓС‚СЊ': 4696350,
#  'СЃРѕРІСЂРµРјРµРЅРЅРѕР№': 4692009,
#  'СЃР±РѕСЂРЅРёРє': 4691124,
#  'РѕС‚С†Р°': 4689698,
#  'РґСЂСѓРіРѕРј': 4685136,
#  'РЅР°Р±Р»СЋРґР°РµС‚СЃСЏ': 4684079,
#  'РѕР±СЉРµРј': 4681733,
#  'РіРµСЂРјР°РЅРёРё': 4670374,
#  'РїРѕРІС‹С€РµРЅРёРµ': 4667534,
#  'РЅРµРјРЅРѕРіРѕ': 4662269,
#  'РґРµР№СЃС‚РІРёС‚РµР»СЊРЅРѕСЃС‚Рё': 4661867,
#  'РѕР±Р°': 4661219,
#  'РІРїРµСЂРµРґ': 4660943,
#  'РїРѕРєР°Р·Р°РЅРѕ': 4658892,
#  'РёРЅРѕР№': 4656438,
#  'СЃРѕР±РѕСЋ': 4654228,
#  'РѕС‚РЅРѕСЃРёС‚СЃСЏ': 4653796,
#  'Р±РѕР»СЊС€РёРµ': 4651674,
#  'РІРѕРІСЃРµ': 4646276,
#  'Р·РЅР°С‚СЊ': 4642142,
#  'РіРѕСЃСѓРґР°СЂСЃС‚РІРѕ': 4639170,
#  'РјРµС‚РѕРґР°': 4638851,
#  'СЂР°Р±РѕС‡РёРµ': 4636065,
#  'С…РѕР·СЏР№СЃС‚РІРѕ': 4633384,
#  'С‡Р°СЃС‚СЊСЋ': 4626929,
#  'РїР°СЂС‚РёСЏ': 4621687,
#  'РїРѕСЃС‚РµРїРµРЅРЅРѕ': 4619483,
#  'СѓРІРµР»РёС‡РµРЅРёРµ': 4617918,
#  'СЂР°Р±РѕС‚Р°С‚СЊ': 4614666,
#  'СЃР»СѓС‡Р°РµРІ': 4613018,
#  'РїРѕРІРѕРґСѓ': 4604793,
#  'РІС‚РѕСЂРѕРіРѕ': 4590436,
#  'РѕР±С‰РµРј': 4585032,
#  'Р¶РµРЅС‰РёРЅС‹': 4583564,
#  'РёРјРµСЋС‚СЃСЏ': 4581625,
#  'С‡Р°СЃРѕРІ': 4575587,
#  'РІРґРѕР»СЊ': 4574861,
#  'СЂР°Р·РІРµ': 4573502,
#  'СЃРєРѕСЂРµРµ': 4570495,
#  'РїСЂРёРІРµРґРµРЅС‹': 4569251,
#  'С†РµРЅС‚СЂ': 4563598,
#  'СЂСЃС„СЃСЂ': 4562097,
#  'РїРѕР»СѓС‡РёР»': 4560406,
#  'СЃРёС…': 4559825,
#  'РЅС‹РЅРµ': 4559733,
#  'РІР°Р¶РЅРѕ': 4556931,
#  'РѕР±СЂР°Р±РѕС‚РєРё': 4548358,
#  'Р·РЅР°РµС‚': 4546613,
#  'СЃРІСЏР·Р°РЅРѕ': 4543331,
#  'РЅРµСЂРµРґРєРѕ': 4531910,
#  'СЃРІСЏР·РµР№': 4526184,
#  'РѕР±С‰РµРµ': 4522276,
#  'РїРѕСЃР»РµРґРЅРёР№': 4520965,
#  'СЃР°РјС‹Рµ': 4520519,
#  'РЅР°С€Рµ': 4511891,
#  'СЃР»РѕРІР°РјРё': 4508681,
#  'РїСЂРѕР±Р»РµРјР°': 4504805,
#  'РіРѕСЂР°Р·РґРѕ': 4503718,
#  'РІРЅРёРјР°РЅРёСЏ': 4498714,
#  'РІСЃРµ-С‚Р°РєРё': 4497330,
#  'СЃС‚СЂСѓРєС‚СѓСЂР°': 4494842,
#  'РёСЃРєСѓСЃСЃС‚РІРѕ': 4492634,
#  'РґР°РЅРЅРѕРј': 4492571,
#  'СЌР»РµРјРµРЅС‚С‹': 4488167,
#  'РЅРѕРІР°СЏ': 4487135,
#  'РјР°С€РёРЅС‹': 4486989,
#  'РїРѕР»РЅРѕР№': 4481970,
#  'РіРµРЅРµСЂР°Р»': 4478891,
#  'СЃР»СѓР¶Р±С‹': 4478195,
#  'СЃРѕС†РёР°Р»СЊРЅРѕР№': 4474497,
#  'РІРѕР№СЃРєР°': 4473134,
#  'РѕС‚Р»РёС‡РёРµ': 4466875,
#  'РїРѕР»СѓС‡РµРЅРёСЏ': 4466836,
#  'С‡Р°СЃС‚РµР№': 4464423,
#  'РІС‹СЂР°Р¶РµРЅРёРµ': 4458897,
#  'СЂРµСЃСѓСЂСЃРѕРІ': 4456929,
#  'РѕРїСЂРµРґРµР»РёС‚СЊ': 4452981,
#  'РїСЂРѕРґСѓРєС‚РѕРІ': 4445891,
#  'РїСЂРµРёРјСѓС‰РµСЃС‚РІРµРЅРЅРѕ': 4438083,
#  'Р°Р·РёРё': 4431388,
#  'Р±РѕР»СЊС€РёРј': 4431365,
#  'С‚РµРѕСЂРёСЏ': 4429969,
#  ...}

# %%
# Print out first 5 elements to demonstrate that dictionary is
# successfully loaded
from itertools import islice

print(list(islice(sym_spell.words.items(), 5)))
# Out:
# []
